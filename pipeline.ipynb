# %%
from google.colab import drive
from glob import glob
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPooling2D, Activation
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.layers.experimental.preprocessing import Rescaling, Resizing
from tensorflow.keras.layers.experimental.preprocessing import RandomZoom, RandomFlip
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam, RMSprop, Adadelta, Nadam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.metrics import BinaryAccuracy, AUC, Precision, Recall, TruePositives, TrueNegatives, FalsePositives, FalseNegatives
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras import applications
from sklearn.metrics import confusion_matrix
import itertools
import datetime
import matplotlib.pyplot as plt
import random
import numpy as np
import os

# %% [markdown]
# # Preparing the data

# %% [markdown]
# This code cell adds a user's google drive to the runtime's file browsing menu, which can be accessed from the left side navigation bar.

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Next, unzip a compressed dataset file to a temporary folder inside the instance. It is important to store the data locally in the runtime instance for use as accessing the google drive repeatedly would severly bottleneck processing.

# %%
# !unzip '/content/drive/MyDrive/datasets/COVID_dataset.zip' -d 'data/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/COVID_dataset/validation/COVID/COVID-2699.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2700.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2701.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2702.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2703.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2704.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2705.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2706.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2707.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2708.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2709.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2710.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2711.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2712.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2713.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2714.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2715.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2716.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2717.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2718.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2719.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2720.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2721.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2722.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2723.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2724.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2725.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2726.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2727.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2728.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2729.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2730.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2731.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2732.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2733.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2734.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2735.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2736.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2737.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2738.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2739.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2740.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2741.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2742.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2743.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2744.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2745.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2746.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2747.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2748.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2749.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2750.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2751.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2752.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2753.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2754.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2755.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2756.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2757.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2758.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2759.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2760.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2761.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2762.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2763.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2764.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2765.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2766.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2767.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2768.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2769.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2770.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2771.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2772.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2773.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2774.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2775.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2776.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2777.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2778.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2779.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2780.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2781.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2782.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2783.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2784.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2785.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2786.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2787.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2788.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2789.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2790.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2791.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2792.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2793.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2794.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2795.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2796.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2797.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2798.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2799.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2800.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2801.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2802.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2803.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2804.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2805.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2806.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2807.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2808.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2809.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2810.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2811.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2812.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2813.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2814.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2815.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2816.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2817.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2818.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2819.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2820.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2821.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2822.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2823.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2824.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2825.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2826.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2827.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2828.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2829.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2830.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2831.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2832.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2833.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2834.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2835.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2836.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2837.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2838.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2839.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2840.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2841.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2842.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2843.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2844.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2845.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2846.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2847.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2848.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2849.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2850.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2851.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2852.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2853.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2854.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2855.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2856.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2857.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2858.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2859.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2860.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2861.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2862.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2863.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2864.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2865.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2866.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2867.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2868.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2869.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2870.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2871.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2872.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2873.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2874.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2875.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2876.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2877.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2878.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2879.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2880.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2881.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2882.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2883.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2884.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2885.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2886.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2887.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2888.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2889.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2890.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2891.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2892.png
#   inflating: data/COVID_dataset/validation/COVID/COVID-2893.png
#    creating: data/COVID_dataset/validation/Normal/
#   inflating: data/COVID_dataset/validation/Normal/Normal-6116.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6118.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6123.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6126.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6128.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6130.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6134.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6135.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6138.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6139.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6140.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6143.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6145.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6148.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6149.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6152.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6153.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6154.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6159.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6162.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6164.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6172.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6174.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6175.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6178.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6182.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6183.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6184.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6189.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6190.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6191.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6193.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6197.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6198.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6201.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6203.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6204.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6205.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6206.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6211.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6212.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6213.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6215.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6216.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6217.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6218.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6219.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6221.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6222.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6225.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6237.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6242.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6244.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6245.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6246.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6247.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6248.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6250.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6251.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6252.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6254.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6258.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6259.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6260.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6261.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6264.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6268.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6271.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6274.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6275.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6277.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6278.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6280.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-6281.png
#   inflating: data/COVID_dataset/validation/Normal/Normal-
print(glob(test_dir + '/*'))
# Out:
# ['data/COVID_dataset/validation', 'data/COVID_dataset/COVID.metadata.xlsx', 'data/COVID_dataset/Normal.metadata.xlsx', 'data/COVID_dataset/train', 'data/COVID_dataset/test']
# ['data/COVID_dataset/train/COVID', 'data/COVID_dataset/train/Normal']
# ['data/COVID_dataset/validation/COVID', 'data/COVID_dataset/validation/Normal']
# ['data/COVID_dataset/test/COVID', 'data/COVID_dataset/test/Normal']

# %% [markdown]
# Further define the class folders of each subfolder and print the number of images in each class folder to the screen. This is to check that the class folders have the same proportional representation in each subfolder.

# %%
# Count number of images in each subfolder in subsets.
train_normal_dir = 'data/COVID_dataset/train/Normal'
print('total training normal images:', len(os.listdir(train_normal_dir)))

train_covid_dir = 'data/COVID_dataset/train/COVID'
print('total training COVID images:', len(os.listdir(train_covid_dir)))

val_normal_dir = 'data/COVID_dataset/validation/Normal'
print('total validation normal images:', len(os.listdir(val_normal_dir)))

val_covid_dir = 'data/COVID_dataset/validation/COVID'
print('total validation COVID images:', len(os.listdir(val_covid_dir)))

test_normal_dir = 'data/COVID_dataset/test/Normal'
print('total test normal images:', len(os.listdir(test_normal_dir)))

test_covid_dir = 'data/COVID_dataset/test/COVID'
print('total test COVID images:', len(os.listdir(test_covid_dir)))
# Out:
# total training normal images: 6115
# total training COVID images: 2170
# total validation normal images: 2038
# total validation COVID images: 723
# total test normal images: 2038
# total test COVID images: 723

# %% [markdown]
# Define an image_dataset_from_directory for visualising a plot of training images.

# %% [markdown]
# **Defining common variables for use in different code cells later in the notebook**:
#
# The chosen dataset contains black-and-white X-ray images of size 299*299, so we defined the image size as such, the colour mode as grayscale, and the number of colour channels as 1. When using colour images, the colour mode would be RGB, and the number of colour channels would be 3. There are only two classes, 'Normal', and 'COVID', so the class mode is binary. A list of class names are defined. This will be passed to image generators defined to specify that the COVID class should be coded as 1, to represent a 'positive' diagnosis of COVID.
#
# Batch size is left to choice. Large batch sizes use more memory when training. An expression for how the pixel values of images should be normalized (converted from integers to floating-points) is also defined. Finally the number of training and validation images are defined for later calculating the number of 'steps' in each set.

# %%
CLASS_NAMES = ['Normal', 'COVID']
BATCH_SIZE = 128
IMG_HEIGHT = 299
IMG_WIDTH = 299
IMG_CHANNELS = 1
IMG_COLOR_MODE = 'grayscale'
IMG_CLASS_MODE = 'binary'
NORMALIZER = 1.0/255

# %% [markdown]
# Count the number of training and validation images.

# %%
TRAIN_IMG_COUNT = len(os.listdir(train_normal_dir)) + len(os.listdir(train_covid_dir))
VALIDATION_IMG_COUNT = len(os.listdir(val_normal_dir)) + len(os.listdir(val_covid_dir))

# %% [markdown]
# # Visualizing the data

# %%
visualise = image_dataset_from_directory(
    train_dir,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=9,
    class_names=CLASS_NAMES,
    shuffle=True
)
# Out:
# Found 8285 files belonging to 2 classes.

# %% [markdown]
# Define a figure using MatPlotLib and plot a random sample of 9 training images with their class labels by taking one batch from the training set and looping through the images. The pixel axis is set to off to save space.

# %%
# Adatped from https://www.tensorflow.org/tutorials/images/classification

plt.figure(figsize=(10,10))
for images, labels in visualise.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(CLASS_NAMES[labels[i]])
    plt.axis('off')
plt.show()

# %% [markdown]
# # Pre-processing the data

# %% [markdown]
# **Define an ImageDataGenerator object for each of the training and validation subfolders:**
#
# These objects will generate preprocessed batches of images. The pixel values of training images are rescaled from integers to floating-point numbers between 0 and 1. This makes training smoother. Each training image is also augmented with a few different, random transformations. Augmenting training images in this way artifically increases the size of the training set. The hope is that a larger training set will give a
#
# Validation images are not augmented. This is because a validation set is used for assessing how different models are performing on data not used in training, and for tuning the hyperparameters of a model. Using different validation data for each model would be an invalid evaluation process.

# %%
train_preprocess = ImageDataGenerator(
    rescale=NORMALIZER,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

validation_preprocess = ImageDataGenerator(rescale=NORMALIZER)

# %% [markdown]
# **Define a batch generator for each training and validation subfolder**:
#
# These generators use the ImageDataGenerator obejcts defined in the previous cell to  call the flow_from_directory method. This method fetch batches of images, preprocessed and augmented by the ImageDataGenerator objects, and resizes them. Classes are defined according to the names of the class folders in each subfolder.

# %%
train_generator = train_preprocess.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    color_mode=IMG_COLOR_MODE,
    class_mode=IMG_CLASS_MODE,
    classes=CLASS_NAMES,
    shuffle=True
)

validation_generator = validation_preprocess.flow_from_directory(
    validation_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    color_mode=IMG_COLOR_MODE,
    class_mode=IMG_CLASS_MODE,
    classes=CLASS_NAMES,  
    shuffle=True
)
# Out:
# Found 8285 images belonging to 2 classes.
# Found 2761 images belonging to 2 classes.

# %% [markdown]
# **Visualising some properties of the training and validation generators:**
#
# This is to make sure that the class names have been mapped to the correct indices (Normal: 0, COVID: 1), and that each generator produces batches of the correct data type, and shape.

# %%
images, labels = train_generator.next()
print("Training generator class indices:", train_generator.class_indices)
print("Batch size:", train_generator.batch_size)
print("Batch data type:", train_generator.dtype)
print("Image batch shape:", images.shape)
print("Label batch shape:", labels.shape)

images, labels = validation_generator.next()
print("\nValidation generator class indices:", validation_generator.class_indices)
print("Batch size:", validation_generator.batch_size)
print("Batch data type:", validation_generator.dtype)
print("Image batch shape:", images.shape)
print("Label batch shape:", labels.shape)
# Out:
# Training generator class indices: {'Normal': 0, 'COVID': 1}
# Batch size: 128
# Batch data type: float32
# Image batch shape: (128, 299, 299, 1)
# Label batch shape: (128,)
#
# Validation generator class indices: {'Normal': 0, 'COVID': 1}
# Batch size: 128
# Batch data type: float32
# Image batch shape: (128, 299, 299, 1)
# Label batch shape: (128,)

# %% [markdown]
# **Visualising the effects of data augmentation on some training samples:**
#
# 1. First choose a class folder in the training subfolder and define its files.
# 2. Count the files in the class folder.
# 3. Define an image path as a selection of a random file.
# 4. Load the image using the defined image path and define its size.
# 5. Convert the image to an array.
# 6. Reshape the image to have a batch dimension of 1 plus its shape (299, 299, 1)
# 7. Define a MatPlotLib figure and a loop for plotting each augmented sample.
# 8. Fetch a batch of size 1 from the training ImageDataGenerator.
# 9. Define 2*2 subplot within the main figure.
# 10. Show each augmented image fetched from the first batch.
# 11. Set the pixel axis to off to save space.
# 12. Increment i by 1 with each image shown, and break the loop after 4 images.
# 13. Show the plotted figure.

# %%
# Adapted from Chollet, F. (2018). Deep learning with Python. Manning, pg 139-140.

fnames = [os.path.join(train_covid_dir, fname) for fname in os.listdir(train_covid_dir)]
file_count = len(os.listdir(train_covid_dir))
img_path = fnames[random.randrange(0, file_count)]
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
x = x.reshape((1,) + x.shape)

i = 0
plt.figure(figsize=(10, 10))
for batch in train_preprocess.flow(x, batch_size=1):
  plt.subplot(2, 2, i + 1)
  img_plot = plt.imshow(image.array_to_img(batch[0]))
  plt.axis("off")
  i += 1
  if i % 4 == 0:
    break
plt.show()

# %% [markdown]
# # Building a model and defining metrics

# %% [markdown]
# **Using Keras' sequential model to define a deep convolutional neural network**:
#
# Standard CNN architectures are made up of convolutional layers which use filters to extract features from an input image and output those features to a feature map, one feature map for each filter. This learning of features is automatic, reducing the need for human driven feature engineering. These feature maps are then stacked and reduced in size by Pooling layers which preserve the core structure of a feature map while reducing its complexity. Features learned by deeper layers are made up of features learned by previous layers. The feature-map outputs of the final MaxPooling layer are passed to a densely connected sub-network for classification. The final layer computes a probaility score, with a score greater than 0.5 being classified as positive (COVID).

# %%
model_name = '1M-6L-ADAM'

model = Sequential(name=model_name)
model.add(InputLayer(input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))

model.add(Conv2D(32, (4, 4), padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(3, 3))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

print(model.summary())
# Out:
# Model: "1M-6L-ADAM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 299, 299, 32)      544
# _________________________________________________________________
# dropout (Dropout)            (None, 299, 299, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 99, 99, 64)        18496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 99, 99, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 49, 49, 64)        36928
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 49, 49, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               590336
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,015,841
# Trainable params: 1,015,841
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# **Defining the appropriate metrics:**
#
# Other metrics must be used alongside accuracy, as accuracy can be a misleading measure of performance for imbalanced datasets if a model simply predicts the majority class everytime, thereby achieving high accuracy with low skill. Precision and recall are informative metrics for getting a sense of how many type 1 errors (false positives) and type 2 errors (false negatives) a model makes. A precision-recall curve summarises the performance of a model according to its precision and recall scores over a range of different classification thresholds by calculating the area underneath the curve.

# %%
metrics = [BinaryAccuracy(name='Accuracy'),
           Precision(name='Precision'), 
           Recall(name='Recall')]

# %% [markdown]
# **Compiling the model:**
#
# Compiling is done by specifying a loss function (also called a cost function), an optimization algorithm, and a list of metrics, which are already defined.
# Cross entropy can be thought of as the distance, between two probability distributions, which in this case are the model's predictions and the expected predictions. This error score is calcluatd for each batch procssed during training and fed into the chosen optimization algorithm, which uses the error as a feedback to adjust the model's weights so that its predictions improve for the next batch.
#
# This is a binary classification problem, as there are only two classes, so binary cross-entropy was chosen for the loss function. Adam was chosen as the optimizer as it is computationally efficient, requires little memory, and is appropriate for problems with many parameters such as this one.

# %%
model.compile(loss=BinaryCrossentropy(),
              optimizer=Adam(learning_rate=0.001),
              metrics=metrics)

# %% [markdown]
# # Training the model and plotting results

# %%
models_dir = '/content/drive/MyDrive/models'
model_dir = os.path.join(models_dir, model_name)
if not os.path.isdir(model_dir):
    os.mkdir(model_dir)

# %% [markdown]
# **Defining callbacks:**
#
# A directory for saving models is defined and a subdirectory is defined as the joining of a model's name to the models directory. A conditinal tests whether a directory for the given model already exists, if it does not, the directory is created and the model is saved as a H5 file.

# %%
checkpoint_dir = model_dir + '/' + model_name + '.{epoch:02d}-{val_loss:.2f}.h5'

# %%
callbacks = [EarlyStopping(monitor='val_loss', mode='min', patience=10, 
                                     restore_best_weights=True),
             
             ModelCheckpoint(filepath=checkpoint_dir, 
                                       monitor='val_loss', 
                                       mode='min', save_best_only=True)]

# %% [markdown]
# **Addressing class imbalance through class weighting:**
#
# By passing a python dictionary when fitting a model to the training data, we can instruct the fitting method to pay closer attention to COVID samples, which are underpresented in the overall dataset, by giving the COVID class a higher weight than the Normal class.

# %%
class_weight = {0: 0.677, 1: 1.909}

# %% [markdown]
# **Training the model:**
#
# The model is fit by passing the training and validtion generators defined during pre-processing. An epoch is one pass through the entire training set, and the steps per epoch in this case is defined by the size of the tranining set divided by the batch size. The same method is used to calculate the number of validation steps.

# %%
# Fit model to training data with end-of-epoch validation.
history = model.fit(
    train_generator,
    epochs=10,
    steps_per_epoch= TRAIN_IMG_COUNT / BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps= VALIDATION_IMG_COUNT / BATCH_SIZE, 
    class_weight=class_weight,
    callbacks=callbacks
)

# %% [markdown]
# **Plotting training results:**
#
# Results are plotted by enumerating over a defined list of strings which define the keys used to access the history of the models performance for each metric. A seperate figure is created for each metric. The x axis for each figure is the number of epochs and the y axis is the value of the metric at the end of each epoch. Each figure plots the training metric against the validation metric. A model name can be specified for the title of the figure. Finally a background grid is included for each figure and a legend for the training and validation plots.

# %%
for i, metric in enumerate(["Accuracy", "Precision", "Recall", "loss"]):
    epochs = range(1, len(history.history[metric]) + 1)
    plt.figure(figsize=(10,4))
    plt.plot(epochs, history.history[metric], c = '#4682B4', marker = 'D')
    plt.plot(epochs, history.history["val_" + metric], c = '#FF8C00', marker = 'D')
    plt.title(model_name + " {}".format(metric))
    plt.xlabel("epochs")
    plt.ylabel(metric)
    plt.grid()
    plt.legend(["train", "val"])
plt.show()

# %% [markdown]
# # Testing a model

# %% [markdown]
# **Defining a test generator:**
#
# The test generator is defined in the same way as the training and validation generators and uses the same pre-processing function as the validation generator (normalization of inputs but no data augmentation).

# %%
test_generator = validation_preprocess.flow_from_directory(
    test_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    color_mode=IMG_COLOR_MODE,
    class_mode=IMG_CLASS_MODE,
    classes=CLASS_NAMES
)
# Out:
# Found 2761 images belonging to 2 classes.

# %% [markdown]
# Get the model's scores for the validation and test data.

# %%
validation = model.evaluate(validation_generator, return_dict=True)
test = model.evaluate(test_generator, return_dict=True)
# Out:
# 22/22 [==============================] - 6s 264ms/step - loss: 0.1532 - Accuracy: 0.9305 - Precision: 0.9053 - Recall: 0.8202 - PR-Curve: 0.9526
# 22/22 [==============================] - 6s 264ms/step - loss: 0.2120 - Accuracy: 0.9037 - Precision: 0.9073 - Recall: 0.7040 - PR-Curve: 0.9168

# %% [markdown]
# Define a function for calculating an F2 score. F2  summarises a model's performance as a weighted harmonic mean.

# %%
def F2_score(precision, recall):
  return ((1 + 2**2) * precision * recall) / (2**2 * precision + recall)

# %% [markdown]
# Print validation results.

# %%
print('Loss = ' + str(validation['loss']))
print('Precision = ' + str(validation['Precision']))
print('Recall = ' + str(validation['Recall']))
print('F2 = ' + str(F2_score(validation['Precision'], validation['Recall'])))
# Out:
# Loss = 0.1532156765460968
# Precision = 0.9053435325622559
# Recall = 0.8201936483383179
# F2 = 0.8359176894154147

# %% [markdown]
# Print the test results.

# %%
print('Loss = ' + str(test['loss']))
print('Precision = ' + str(test['Precision']))
print('Recall = ' + str(test['Recall']))
print('F2 = ' + str(F2_score(test['Precision'], test['Recall'])))
# Out:
# Loss = 0.21200472116470337
# Precision = 0.9073083996772766
# Recall = 0.704011082649231
# F2 = 0.7370402731946708
